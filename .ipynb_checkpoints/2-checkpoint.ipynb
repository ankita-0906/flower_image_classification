# %%
# ============================
# Part A — Setup & Helper Funcs
# ============================

import os
import random
import shutil
from pathlib import Path
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline

DATA_DIR = "flowers"        # ✅ Update if dataset path is different
SUBSET_BASE = "subsets"     # Output folder for subsets

def count_images_per_class(src_dir):
    src = Path(src_dir)
    return {cls.name: len(list(cls.glob("*.*"))) 
            for cls in src.iterdir() if cls.is_dir()}

def show_random_images(src_dir):
    src = Path(src_dir)
    classes = [c.name for c in src.iterdir() if c.is_dir()]
    plt.figure(figsize=(12, 5))
    for i, cls in enumerate(classes):
        cls_dir = src / cls
        img = random.choice(list(cls_dir.glob("*.*")))
        img = Image.open(img).convert("RGB")
        plt.subplot(1, len(classes), i+1)
        plt.imshow(img)
        plt.title(cls)
        plt.axis("off")
    plt.show()

def make_subset(src_dir, dst_dir, per_class=100, seed=42):
    random.seed(seed)
    src = Path(src_dir)
    dst = Path(dst_dir)
    if dst.exists():
        shutil.rmtree(dst)
    dst.mkdir(parents=True, exist_ok=True)

    for cls in src.iterdir():
        if cls.is_dir():
            files = list(cls.glob("*.*"))
            chosen = random.sample(files, min(per_class, len(files)))
            cls_dst = dst / cls.name
            cls_dst.mkdir(parents=True, exist_ok=True)
            for img in chosen:
                shutil.copy(img, cls_dst / img.name)

    return count_images_per_class(dst_dir)


# ✅ Run Counting & Random Display
print("Original dataset counts:")
print(count_images_per_class(DATA_DIR))

show_random_images(DATA_DIR)

# ✅ Create subset (200 images per class)
subset200_path = os.path.join(SUBSET_BASE, "subset_200")
print("\nCreating subset_200...")
print(make_subset(DATA_DIR, subset200_path, per_class=200))

print("\nCounts in subset_200:")
print(count_images_per_class(subset200_path))
# Out:
# Original dataset counts:
# {'daisy': 633, 'dandelion': 898, 'roses': 641, 'sunflowers': 699, 'tulips': 799}
# Creating subset_200...
# {'daisy': 200, 'dandelion': 200, 'roses': 200, 'sunflowers': 200, 'tulips': 200}
#
# Counts in subset_200:
# {'daisy': 200, 'dandelion': 200, 'roses': 200, 'sunflowers': 200, 'tulips': 200}

# %%
# ============================
# Part B — Data Loading & Augmentation
# ============================

import tensorflow as tf

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

def load_data(subset_dir):
    train_ds = tf.keras.utils.image_dataset_from_directory(
        subset_dir,
        validation_split=0.2,
        subset="training",
        seed=42,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE
    )
    val_ds = tf.keras.utils.image_dataset_from_directory(
        subset_dir,
        validation_split=0.2,
        subset="validation",
        seed=42,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE
    )

    # Prefetch for performance
    return train_ds.prefetch(AUTOTUNE), val_ds.prefetch(AUTOTUNE), train_ds.class_names


# ✅ Load Data After Subset Creation
train_ds, val_ds, class_names = load_data(subset200_path)
print("\nClasses Loaded:", class_names)
# Out:
# Found 1000 files belonging to 5 classes.
# Using 800 files for training.
# Found 1000 files belonging to 5 classes.
# Using 200 files for validation.
#
# Classes Loaded: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.2)
])

def visualize_aug():
    for imgs, _ in train_ds.take(1):
        sample = imgs[0]
        plt.figure(figsize=(10, 3))
        for i in range(5):
            aug_img = data_augmentation(tf.expand_dims(sample, 0))
            plt.subplot(1, 5, i+1)
            plt.imshow(aug_img[0].numpy().astype("uint8"))
            plt.axis("off")
        plt.show()

visualize_aug()

# %%
# ============================
# Part C — Scratch CNN Model
# ============================

from tensorflow.keras import layers, models

def make_scratch_model(num_classes=5):
    model = models.Sequential([
        layers.Rescaling(1./255, input_shape=IMG_SIZE + (3,)),
        layers.Conv2D(32, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Conv2D(128, 3, activation='relu', padding='same'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

model = make_scratch_model()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# ✅ Train Model
EPOCHS = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)
# Out:
# C:\Users\Swarnadwip_Sarkar\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 100352)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      12,845,184 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,939,077 (49.36 MB)
#  Trainable params: 12,939,077 (49.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.2925 - loss: 1.7764 - val_accuracy: 0.4950 - val_loss: 1.2385
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - accuracy: 0.4762 - loss: 1.2170 - val_accuracy: 0.4800 - val_loss: 1.1708
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.5725 - loss: 1.0485 - val_accuracy: 0.5950 - val_loss: 1.1397
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - accuracy: 0.7038 - loss: 0.8178 - val_accuracy: 0.5300 - val_loss: 1.1462
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.7937 - loss: 0.5885 - val_accuracy: 0.6000 - val_loss: 1.2817
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.8988 - loss: 0.3359 - val_accuracy: 0.5950 - val_loss: 1.4416
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.9287 - loss: 0.2118 - val_accuracy: 0.5600 - val_loss: 1.7664
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.9650 - loss: 0.1251 - val_accuracy: 0.5850 - val_loss: 1.9497
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.9688 - loss: 0.0880 - val_accuracy: 0.5600 - val_loss: 2.6670
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 67s 3s/step - accuracy: 0.9812 - loss: 0.0646 - val_accuracy: 0.5200 - val_loss: 2.7668
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.9787 - loss: 0.1067 - val_accuracy: 0.5650 - val_loss: 2.3326
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.9837 - loss: 0.0822 - val_accuracy: 0.5350 - val_loss: 3.0517
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9675 - loss: 0.1078 - val_accuracy: 0.5500 - val_loss: 3.3062
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 892ms/step - accuracy: 0.9900 - loss: 0.0281 - val_accuracy: 0.5050 - val_loss: 3.7109
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 898ms/step - accuracy: 0.9925 - loss: 0.0291 - val_accuracy: 0.5300 - val_loss: 3.5872
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 915ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.5100 - val_loss: 4.1575
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 935ms/step - accuracy: 0.9987 - loss: 0.0031 - val_accuracy: 0.5450 - val_loss: 4.4519
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 936ms/step - accuracy: 0.9975 - loss: 0.0050 - val_accuracy: 0.5350 - val_loss: 4.1377
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 920ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5600 - val_loss: 4.2610
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 908ms/step - accuracy: 1.0000 - loss: 6.3436e-04 - val_accuracy: 0.5600 - val_loss: 4.3528

# %%
# Plotting training history:
import pandas as pd
def plot_history(history):
    import matplotlib.pyplot as plt
    plt.figure(figsize=(8,4))
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
plot_history(history)

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

# %%
# Part D: Transfer learning templates
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

def make_transfer_model(img_size=IMG_SIZE, num_classes=5, base_trainable=False):
    base = MobileNetV2(weights='imagenet', include_top=False, input_shape=img_size + (3,))
    base.trainable = base_trainable
    inputs = layers.Input(shape=img_size + (3,))
    x = layers.Rescaling(1./255)(inputs)
    x = base(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inputs, outputs, name='mobilenetv2_transfer')
    return model

# Frozen model (train only head)
frozen_model = make_transfer_model(base_trainable=False)
frozen_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
frozen_model.summary()

# Fine-tune top 20 layers (unfreeze)
def fine_tune_model(model, base_layers_to_unfreeze=20):
    # attempt to locate MobileNetV2 base in model
    base = None
    for layer in model.layers:
        if hasattr(layer, 'output') and 'MobilenetV2' in layer.name.lower() or isinstance(layer, tf.keras.applications.MobileNetV2):
            base = layer
            break
    # fallback: assume layer index 2 is base (may vary)
    if base is None:
        base = model.layers[2]
    # set trainability
    total_layers = len(base.layers)
    for layer in base.layers[:-base_layers_to_unfreeze]:
        layer.trainable = False
    for layer in base.layers[-base_layers_to_unfreeze:]:
        layer.trainable = True
    # recompile with lower LR
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-5),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

print('Transfer learning templates ready. To train, create datasets with load_datasets_from_directory() and call model.fit()')
# Out:
# Model: "mobilenetv2_transfer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 5)                   │           6,405 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,264,389 (8.64 MB)
#  Trainable params: 6,405 (25.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Transfer learning templates ready. To train, create datasets with load_datasets_from_directory() and call model.fit()

# %%
# Part E: Evaluation & Reporting templates
import numpy as np
import os
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

def model_size_mb(model_path):
    """Return file size in MB for saved model directory/file."""
    if os.path.isdir(model_path):
        # size of directory
        total = 0
        for dirpath, dirnames, filenames in os.walk(model_path):
            for f in filenames:
                fp = os.path.join(dirpath, f)
                total += os.path.getsize(fp)
        return total / (1024*1024)
    else:
        return os.path.getsize(model_path) / (1024*1024)

def evaluate_and_report(model, val_ds, class_names):
    # Collect true labels and predictions
    y_true = []
    y_pred = []
    for images, labels in val_ds:
        preds = model.predict(images)
        preds_labels = np.argmax(preds, axis=1)
        y_true.extend(labels.numpy().tolist())
        y_pred.extend(preds_labels.tolist())
    print('Classification Report:')
    print(classification_report(y_true, y_pred, target_names=class_names))
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

def save_best_model(model, path='best_flower_model.keras'):
    model.save(path)
    print('Saved model to', path)
    print('Model size (MB):', model_size_mb(path))

def predict_image(model, image_path, class_names, img_size=IMG_SIZE):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=img_size)
    arr = tf.keras.preprocessing.image.img_to_array(img)
    arr = arr / 255.0
    arr = np.expand_dims(arr, 0)
    preds = model.predict(arr)
    idx = np.argmax(preds[0])
    return class_names[idx], preds[0][idx]

# Usage example (run after training and when you have val_ds and class_names):
# evaluate_and_report(best_model, val_ds, class_names)
# save_best_model(best_model, 'best_flower_model.keras')
# print(predict_image(best_model, 'path/to/some/image.jpg', class_names))
